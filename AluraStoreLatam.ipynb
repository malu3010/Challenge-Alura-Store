# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/malu3010/Challenge-Alura-Store/refs/heads/main/base_de_datos_challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/malu3010/Challenge-Alura-Store/refs/heads/main/base_de_datos_challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/malu3010/Challenge-Alura-Store/refs/heads/main/base_de_datos_challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/malu3010/Challenge-Alura-Store/refs/heads/main/base_de_datos_challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %%
tienda.head()
#tienda2.head()
#tienda3.head()
#tienda4.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación
# #####En este primer análisis, se calcula el **ingreso total** de cada tienda. Para esto, se sumaran los valores de la columna **Precio** de cada conjunto de datos de la tienda.

# %%
precio_tienda1 = tienda['Precio'].sum()
precio_tienda2 = tienda2['Precio'].sum()
precio_tienda3 = tienda3['Precio'].sum()
precio_tienda4 = tienda4['Precio'].sum()

precio_tiendas = [precio_tienda1,precio_tienda2,precio_tienda3,precio_tienda4]

for i in range(len(precio_tiendas)):
  print(f'El ingreso total de la tienda {i+1} es {precio_tiendas[i]}')
# Out:
# El ingreso total de la tienda 1 es 1150880400.0
# El ingreso total de la tienda 2 es 1116343500.0
# El ingreso total de la tienda 3 es 1098019600.0
# El ingreso total de la tienda 4 es 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría
# #####En este segundo añalisis, se calcula la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
'''Forma 1:
conteo_cat_tienda1 = tienda['Categoría del Producto'].value_counts()
cant_prod_por_cat_tienda1 = []
for categoria,cantidad in conteo_cat_tienda1.items():
  cant_prod_por_cat_tienda1.append([categoria,cantidad])

cant_prod_por_cat_tienda1'''
# Out:
# [['Muebles', 465],
#  ['Electrónicos', 448],
#  ['Juguetes', 324],
#  ['Electrodomésticos', 312],
#  ['Deportes y diversión', 284],
#  ['Instrumentos musicales', 182],
#  ['Libros', 173],
#  ['Artículos para el hogar', 171]]

# %%
# Forma 2: Aplicando List Comprehension
#.value_counts(): cuenta cuántas veces aparece cada categoría
#.items(): convierte esa Serie en un iterable de pares clave-valor

cant_prod_por_cat_tienda1 = [[categoria,cantidad] for categoria,cantidad in tienda['Categoría del Producto'].value_counts().items()]
print(f'La cantidad de productos vendidos por categoría para la tienda 1 es: \n{cant_prod_por_cat_tienda1}')

cant_prod_por_cat_tienda2 = [[categoria,cantidad] for categoria,cantidad in tienda2['Categoría del Producto'].value_counts().items()]
print(f'\nLa cantidad de productos vendidos por categoría para la tienda 1 es: \n{cant_prod_por_cat_tienda2}')

cant_prod_por_cat_tienda3 = [[categoria,cantidad] for categoria,cantidad in tienda3['Categoría del Producto'].value_counts().items()]
print(f'\nLa cantidad de productos vendidos por categoría para la tienda 1 es: \n{cant_prod_por_cat_tienda3}')

cant_prod_por_cat_tienda4 = [[categoria,cantidad] for categoria,cantidad in tienda4['Categoría del Producto'].value_counts().items()]
print(f'\nLa cantidad de productos vendidos por categoría para la tienda 1 es: \n{cant_prod_por_cat_tienda4}')
# Out:
# La cantidad de productos vendidos por categoría para la tienda 1 es:
# [['Muebles', 465], ['Electrónicos', 448], ['Juguetes', 324], ['Electrodomésticos', 312], ['Deportes y diversión', 284], ['Instrumentos musicales', 182], ['Libros', 173], ['Artículos para el hogar', 171]]
#
# La cantidad de productos vendidos por categoría para la tienda 1 es:
# [['Muebles', 442], ['Electrónicos', 422], ['Juguetes', 313], ['Electrodomésticos', 305], ['Deportes y diversión', 275], ['Instrumentos musicales', 224], ['Libros', 197], ['Artículos para el hogar', 181]]
#
# La cantidad de productos vendidos por categoría para la tienda 1 es:
# [['Muebles', 499], ['Electrónicos', 451], ['Juguetes', 315], ['Electrodomésticos', 278], ['Deportes y diversión', 277], ['Libros', 185], ['Instrumentos musicales', 177], ['Artículos para el hogar', 177]]
#
# La cantidad de productos vendidos por categoría para la tienda 1 es:
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda
# #####En este tercer análisis, se calcula las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calif_prom_tienda1 = round(float(tienda['Calificación'].sum()/len(tienda['Calificación'])),2)
calif_prom_tienda2 = round(float(tienda2['Calificación'].sum()/len(tienda2['Calificación'])),2)
calif_prom_tienda3 = round(float(tienda3['Calificación'].sum()/len(tienda3['Calificación'])),2)
calif_prom_tienda4 = round(float(tienda4['Calificación'].sum()/len(tienda4['Calificación'])),2)

calif_prom_tiendas = [calif_prom_tienda1,calif_prom_tienda2,calif_prom_tienda3,calif_prom_tienda4]

for i in range(len(calif_prom_tiendas)):
  print(f'La calificación promedio de la tienda {i+1} es {calif_prom_tiendas[i]}')
# Out:
# La calificación promedio de la tienda 1 es 3.98
# La calificación promedio de la tienda 2 es 4.04
# La calificación promedio de la tienda 3 es 4.05
# La calificación promedio de la tienda 4 es 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos
# #####En este cuarto análisis, se identifica qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
# Aplicando Dict Comprehension

prod_vendidos_tienda1 = {
    '5 productos más vendidos': [[producto,cantidad] for producto,cantidad in tienda['Producto'].value_counts().head(5).items()],
    '5 productos menos vendidos': [[producto,cantidad] for producto,cantidad in tienda['Producto'].value_counts().tail(5).items()]
}
print(f'El resumen de productos más y menos vendidos para la tienda 1 es: \n{prod_vendidos_tienda1}')

prod_vendidos_tienda2 = {
    '5 productos más vendidos': [[producto,cantidad] for producto,cantidad in tienda2['Producto'].value_counts().head(5).items()],
    '5 productos menos vendidos': [[producto,cantidad] for producto,cantidad in tienda2['Producto'].value_counts().tail(5).items()]
}
print(f'\nEl resumen de productos más y menos vendidos para la tienda 2 es: \n{prod_vendidos_tienda2}')

prod_vendidos_tienda3 = {
    '5 productos más vendidos': [[producto,cantidad] for producto,cantidad in tienda3['Producto'].value_counts().head(5).items()],
    '5 productos menos vendidos': [[producto,cantidad] for producto,cantidad in tienda3['Producto'].value_counts().tail(5).items()]
}
print(f'\nEl resumen de productos más y menos vendidos para la tienda 3 es: \n{prod_vendidos_tienda3}')

prod_vendidos_tienda4 = {
    '5 productos más vendidos': [[producto,cantidad] for producto,cantidad in tienda4['Producto'].value_counts().head(5).items()],
    '5 productos menos vendidos': [[producto,cantidad] for producto,cantidad in tienda4['Producto'].value_counts().tail(5).items()]
}
print(f'\nEl resumen de productos más y menos vendidos para la tienda 4 es: \n{prod_vendidos_tienda4}')
# Out:
# El resumen de productos más y menos vendidos para la tienda 1 es:
# {'5 productos más vendidos': [['Microondas', 60], ['TV LED UHD 4K', 60], ['Armario', 60], ['Secadora de ropa', 58], ['Mesa de noche', 56]], '5 productos menos vendidos': [['Ciencia de datos con Python', 39], ['Pandereta', 36], ['Olla de presión', 35], ['Auriculares con micrófono', 33], ['Celular ABXY', 33]]}
#
# El resumen de productos más y menos vendidos para la tienda 2 es:
# {'5 productos más vendidos': [['Iniciando en programación', 65], ['Microondas', 62], ['Batería', 61], ['Guitarra acústica', 58], ['Pandereta', 58]], '5 productos menos vendidos': [['Auriculares', 37], ['Sillón', 35], ['Mesa de comedor', 34], ['Impresora', 34], ['Juego de mesa', 32]]}
#
# El resumen de productos más y menos vendidos para la tienda 3 es:
# ...

# %% [markdown]
# # 5. Envío promedio por tienda
# #####En este quinto análisis, se calcula el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
cost_envio_prom_tienda1 = round(float(tienda['Costo de envío'].sum()/len(tienda['Costo de envío'])),2)
cost_envio_prom_tienda2 = round(float(tienda2['Costo de envío'].sum()/len(tienda2['Costo de envío'])),2)
cost_envio_prom_tienda3 = round(float(tienda3['Costo de envío'].sum()/len(tienda3['Costo de envío'])),2)
cost_envio_prom_tienda4 = round(float(tienda4['Costo de envío'].sum()/len(tienda4['Costo de envío'])),2)

cost_envio_prom_tiendas = [cost_envio_prom_tienda1,cost_envio_prom_tienda2,cost_envio_prom_tienda3,cost_envio_prom_tienda4]

for i in range(len(cost_envio_prom_tiendas)):
  print(f'El costo de envío promedio de la tienda {i+1} es {cost_envio_prom_tiendas[i]}')
# Out:
# El costo de envío promedio de la tienda 1 es 26018.61
# El costo de envío promedio de la tienda 2 es 25216.24
# El costo de envío promedio de la tienda 3 es 24805.68
# El costo de envío promedio de la tienda 4 es 23459.46

# %% [markdown]
# #Visualización
# #####Los gráficos complementan el análisis realizado, resaltando los puntos más relevantes, como los ingresos de la tienda, la distribución de categorías de productos, las opiniones de los clientes, los productos más vendidos y/o los costes de envío.

# %%
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
# Gráfica de líneas del ingreso total por tienda
plt.figure(figsize=(8,5)) # Crea una nueva figura
tiendas = ['Tienda 1','Tienda 2','Tienda 3','Tienda 4']
plt.plot(tiendas,precio_tiendas,marker='o', linestyle='-', color='blue')
plt.ylabel("Ingreso Total")
plt.title("Ingreso Total por Tienda")
# Out:
# Text(0.5, 1.0, 'Ingreso Total por Tienda')

# %%
# Gráfica de barras de la cantidad de Productos Vendidos por Categoría para la Tienda 1
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in cant_prod_por_cat_tienda1],height=[item[1] for item in cant_prod_por_cat_tienda1])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("Cantidad de Productos Vendidos por Categoría - Tienda 1")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad

# Gráfica de barras de la cantidad de Productos Vendidos por Categoría para la Tienda 2
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in cant_prod_por_cat_tienda2],height=[item[1] for item in cant_prod_por_cat_tienda2])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("Cantidad de Productos Vendidos por Categoría - Tienda 2")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad

# Gráfica de barras de la cantidad de Productos Vendidos por Categoría para la Tienda 3
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in cant_prod_por_cat_tienda3],height=[item[1] for item in cant_prod_por_cat_tienda3])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("Cantidad de Productos Vendidos por Categoría - Tienda 3")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad

# Gráfica de barras de la cantidad de Productos Vendidos por Categoría para la Tienda 4
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in cant_prod_por_cat_tienda4],height=[item[1] for item in cant_prod_por_cat_tienda4])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("Cantidad de Productos Vendidos por Categoría - Tienda 4")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Muebles'),
#   Text(1, 0, 'Electrónicos'),
#   Text(2, 0, 'Juguetes'),
#   Text(3, 0, 'Deportes y diversión'),
#   Text(4, 0, 'Electrodomésticos'),
#   Text(5, 0, 'Artículos para el hogar'),
#   Text(6, 0, 'Libros'),
#   Text(7, 0, 'Instrumentos musicales')])

# %%
# Gráfica de líneas de la calificación promedio por tienda
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.plot(tiendas,calif_prom_tiendas,marker='o', linestyle='-', color='red')
plt.ylabel("Calificación Promedio")
plt.title("Calificación Promedio por Tienda")
# Out:
# Text(0.5, 1.0, 'Calificación Promedio por Tienda')

# %%
# Gráfica de líneas del costo de envío por tienda
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.plot(tiendas,cost_envio_prom_tiendas,marker='o', linestyle='-', color='purple')
plt.ylabel("Costo de Envío Promedio")
plt.title("Costo de Envío Promedio por Tienda")
# Out:
# Text(0.5, 1.0, 'Costo de Envío Promedio por Tienda')

# %%
# Gráfica de barras de los productos más vendidos para la Tienda 1
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in prod_vendidos_tienda1['5 productos más vendidos']],height=[item[1] for item in prod_vendidos_tienda1['5 productos más vendidos']])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("5 Productos Más Vendidos - Tienda 1")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad

# Gráfica de barras de los productos más vendidos para la Tienda 2
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in prod_vendidos_tienda2['5 productos más vendidos']],height=[item[1] for item in prod_vendidos_tienda2['5 productos más vendidos']])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("5 Productos Más Vendidos - Tienda 2")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad

# Gráfica de barras de los productos más vendidos para la Tienda 3
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in prod_vendidos_tienda3['5 productos más vendidos']],height=[item[1] for item in prod_vendidos_tienda3['5 productos más vendidos']])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("5 Productos Más Vendidos - Tienda 3")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad

# Gráfica de barras de los productos más vendidos para la Tienda 4
plt.figure(figsize=(8,5)) # Crea una nueva figura
plt.bar(x=[item[0] for item in prod_vendidos_tienda4['5 productos más vendidos']],height=[item[1] for item in prod_vendidos_tienda4['5 productos más vendidos']])
plt.xlabel("Producto")
plt.ylabel("Cantidad")
plt.title("5 Productos Más Vendidos - Tienda 4")
plt.xticks(rotation=45, ha='right') #Rota las etiquetas del eje x para mayor legibilidad
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Cama box'),
#   Text(1, 0, 'Cubertería'),
#   Text(2, 0, 'Dashboards con Power BI'),
#   Text(3, 0, 'Cama king'),
#   Text(4, 0, 'Carrito de control remoto')])
